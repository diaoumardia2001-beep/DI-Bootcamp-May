# %% [markdown]
# ## Exercise 1 : Matrix Operations
# Instructions
# In this exercise, you’ll work with a 3x3 matrix. Here’s a brief explanation of the concepts:
#
# Determinant: The determinant is a value that can be computed from the elements of a square matrix. It provides important information about the matrix, such as whether it has an inverse, and is used in various areas like linear algebra and calculus. To understand more about it you can watch this video.
# Inverse of a Matrix: The inverse of a matrix is a matrix that, when multiplied with the original matrix, results in an identity matrix. Not all matrices have inverses. The inverse is crucial in solving systems of linear equations.
# Create a 3x3 matrix and perform the following operations:
#
# Calculate the determinant.
# Find the inverse of the matrix.

# %%
import numpy as np


matrix = np.array([[4, 7, 2],
                  [3, 6, 1],
                  [2, 5, 1]])


det = np.linalg.det(matrix)


inverse_matrix = np.linalg.inv(matrix)

print(f"Determinant: {det:.2f}\n")
print("Inverse Matrix:\n", inverse_matrix)
# Out:
# Determinant: 3.00
#
# Inverse Matrix:
#  [[ 0.33333333  1.         -1.66666667]
#  [-0.33333333  0.          0.66666667]
#  [ 1.         -2.          1.        ]]

# %% [markdown]
# ## Exercise 2 : Statistical Analysis
# Instructions
# In this exercise, you’ll calculate statistical measures for a dataset:
#
# Mean: The average value of a dataset.
# Median: The middle value in a dataset when it is arranged in ascending or descending order.
# Standard Deviation: A measure of the amount of variation or dispersion in a set of values.
# Using NumPy, generate an array of 50 random numbers and compute:
#
# The mean and median.
# The standard deviation.

# %%
np.random.seed(42)
data = np.random.uniform(0, 100, 50)


mean_val = np.mean(data)
median_val = np.median(data)
std_dev = np.std(data)

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
# Out:
# Mean: 44.59
# Median: 43.60
# Standard Deviation: 28.60

# %% [markdown]
# ## Exercise 3 : Date Manipulation
# Instructions
# Create a NumPy array of dates for the month of January 2023. Convert these dates to another format (e.g., YYYY/MM/DD).

# %%
import pandas as pd
dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')

formatted_dates = pd.to_datetime(dates).strftime('%Y/%m/%d')

print("Original NumPy array samples:", dates[:3])
print("Formatted date samples:", formatted_dates[:3])
# Out:
# Original NumPy array samples: ['2023-01-01' '2023-01-02' '2023-01-03']
# Formatted date samples: Index(['2023/01/01', '2023/01/02', '2023/01/03'], dtype='str')

# %% [markdown]
# ## Exercise 4 : Data Manipulation with NumPy and Pandas
# Instructions
# Create a DataFrame with random numbers and perform:
#
# Conditional selection of data.
# Aggregation functions like sum and average.

# %%
np.random.seed(10)
df = pd.DataFrame(np.random.randint(10, 100, size=(5, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:\n", df, "\n")

filtered_df = df[df['A'] > 50]
print("Rows where A > 50:\n", filtered_df, "\n")


print(f"Sum of columns:\n{df.sum()}")
print(f"Average of columns:\n{df.mean()}")
# Out:
# Original DataFrame:
#      A   B   C
# 0  19  25  74
# 1  38  99  39
# 2  18  83  10
# 3  50  46  26
# 4  21  64  98
#
# Rows where A > 50:
#  Empty DataFrame
# Columns: [A, B, C]
# Index: []
#
# Sum of columns:
# A    146
# B    317
# C    247
# dtype: int64
# Average of columns:
# A    29.2
# B    63.4
# C    49.4
# dtype: float64

# %% [markdown]
# ## Exercise 5 : Image Representation
# Instructions
# Explain how images are represented in NumPy arrays and demonstrate with a simple example (e.g., creating a 5x5 grayscale image).

# %%
import matplotlib.pyplot as plt


image_array = np.array([
    [0,   0,   255, 0,   0],
    [0,   0,   255, 0,   0],
    [255, 255, 255, 255, 255],
    [0,   0,   255, 0,   0],
    [0,   0,   255, 0,   0]
])

print("NumPy Array representation:\n", image_array)


plt.imshow(image_array, cmap='gray', vmin=0, vmax=255)
plt.title("5x5 Grayscale Image Matrix")
plt.axis('off') # Hide pixel grid coordinate lines
plt.show()
# Out:
# NumPy Array representation:
#  [[  0   0 255   0   0]
#  [  0   0 255   0   0]
#  [255 255 255 255 255]
#  [  0   0 255   0   0]
#  [  0   0 255   0   0]]

# %% [markdown]
# ## Exercise 6 : Basic Hypothesis Testing
# Instructions
# Create a sample dataset to test the effectiveness of a new training program on employee productivity:
#
#
# import numpy as np
#
# # Productivity scores of employees before the training program
# productivity_before = np.random.normal(loc=50, scale=10, size=30)
#
# # Productivity scores of the same employees after the training program
# productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)
#
# # Your task is to formulate a hypothesis regarding the training program's effectiveness
# # and test it using basic statistical functions in NumPy.

# %%
np.random.seed(42)
productivity_before = np.random.normal(loc=50, scale=10, size=30)
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

improvements = productivity_after - productivity_before
mean_improvement = np.mean(improvements)

print(f"Average productivity change: +{mean_improvement:.2f} points.")

if mean_improvement > 0:
    print("Conclusion: Reject H0. The training program positively impacts employee productivity.")
else:
    print("Conclusion: Fail to reject H0. No metric proof of improvement.")
# Out:
# Average productivity change: +4.64 points.
# Conclusion: Reject H0. The training program positively impacts employee productivity.

# %% [markdown]
# ## Exercise 7 : Complex Array Comparison
# Instructions
# Create two arrays and perform element-wise comparison to find which elements are greater in the first array.
#
# The expected output is a boolean array showing which elements in the first array are greater than the corresponding elements in the second array.

# %%
array1 = np.array([10, 35, 50, 22, 90])
array2 = np.array([12, 30, 50, 15, 95])

greater_mask = array1 > array2

print("Array 1:       ", array1)
print("Array 2:       ", array2)
print("Is Array1 > Array2?", greater_mask)
# Out:
# Array 1:        [10 35 50 22 90]
# Array 2:        [12 30 50 15 95]
# Is Array1 > Array2? [False  True False  True False]

# %% [markdown]
# ## Exercise 8 : Time Series Data Manipulation
# Instructions
# Generate time series data for the year 2023. Demonstrate slicing for the following intervals:
#
# January to March
# April to June
# July to September
# October to December
# Generate a time series data for a specific period and demonstrate how to slice this data for different intervals.

# %%
time_index = pd.date_range(start="2023-01-01", end="2023-12-31", freq="D")

time_series_data = pd.Series(np.random.randn(len(time_index)), index=time_index)

q1_data = time_series_data["2023-01":"2023-03"]
q2_data = time_series_data["2023-04":"2023-06"]
q3_data = time_series_data["2023-07":"2023-09"]
q4_data = time_series_data["2023-10":"2023-12"]

print(f"January to March Data Points:   {len(q1_data)}")
print(f"April to June Data Points:       {len(q2_data)}")
print(f"July to September Data Points:  {len(q3_data)}")
print(f"October to December Data Points: {len(q4_data)}")
# Out:
# January to March Data Points:   90
# April to June Data Points:       91
# July to September Data Points:  92
# October to December Data Points: 92

# %% [markdown]
# ## Exercise 9 : Data Conversion
# Instructions
# Demonstrate how to convert a NumPy array to a Pandas DataFrame and vice versa.

# %%
np_array = np.array([[1, 2, 3], [4, 5, 6]])
df_converted = pd.DataFrame(np_array, columns=['Col1', 'Col2', 'Col3'])
print("Pandas DataFrame output:\n", df_converted, "\n")

array_converted = df_converted.to_numpy()
print("Back to NumPy array:\n", array_converted)
# Out:
# Pandas DataFrame output:
#     Col1  Col2  Col3
# 0     1     2     3
# 1     4     5     6
#
# Back to NumPy array:
#  [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## Exercise 10 : Basic Visualization
# Instructions
# Use Matplotlib to visualize a simple dataset created with NumPy (e.g., a line graph of random numbers).

# %%
np.random.seed(5)
x_steps = np.arange(1, 51)
y_values = np.random.randn(50).cumsum() 

plt.figure(figsize=(9, 4.5))
plt.plot(x_steps, y_values, marker='o', color='#3498db', linestyle='-', linewidth=2, markersize=4)

plt.title('Time Evolution Random Tracking Graph', fontsize=12)
plt.xlabel('Steps Sequence Index')
plt.ylabel('Value Scope Metrics')
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()
